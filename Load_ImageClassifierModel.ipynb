# %% [markdown]
# # Load Image Classifier from G-Drive
# Pretrained Model

# %% [markdown]
# ## Import FastAI

# %%
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
from fastbook import *
from fastai.vision.widgets import *

# %%
import os

# %% [markdown]
# ## Load the Learner

# %%
learn_inf = load_learner('/content/gdrive/MyDrive/images/CatBreedFinal.pkl')

# %%
learn_inf.dls.vocab
# Out:
# ['Abyssinian Cat', 'American Bobtail Cat', 'American Curl Cat', 'American Shorthair Cat', 'Bombay Cat', 'British Shorthair Cat', 'Devon Rex Cat', 'Himalayan Cat', 'Maine Coon Cat', 'Munchkin Cat', 'Oriental Shorthairs Cat', 'Persian Cat', 'Ragdoll Cat', 'Scottish fold Cat', 'Siamese Cat', 'Singapura Cat', 'Somali Cat', 'Spotted Cat', 'The Birman Cat', 'cats']

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %% [markdown]
# ## Upload Image

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: Siamese Cat; Probability: 0.9948')

# %%
btn_upload = widgets.FileUpload()
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])

# %% [markdown]
# ## Upload Image from Drive

# %% [markdown]
# ### Tensor output

# %%
learn_inf.predict('/content/gdrive/MyDrive/Kaggle/DSC_0527.JPG')
# Out:
# ('Ragdoll Cat',
#  tensor(12),
#  tensor([2.5168e-04, 3.2488e-04, 2.2253e-01, 2.7962e-03, 6.3584e-03, 3.4179e-02, 6.7233e-04, 2.6538e-02, 1.2150e-01, 5.9273e-03, 2.8574e-03, 1.2109e-01, 3.6330e-01, 1.2460e-02, 3.2525e-03, 3.5407e-03,
#          2.7272e-02, 1.0933e-03, 3.7794e-02, 6.2613e-03]))

# %% [markdown]
# ### Normal Output

# %%
driveimage =(PILImage.create('/content/gdrive/MyDrive/Kaggle/DSC_0527.JPG'))

# %%
pred,pred_idx,probs = learn_inf.predict(driveimage)

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(driveimage.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: Ragdoll Cat; Probability: 0.3633')
